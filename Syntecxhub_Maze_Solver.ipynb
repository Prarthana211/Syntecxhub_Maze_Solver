# %% [markdown]
# <a href="https://colab.research.google.com/github/Prarthana211/Syntecxhub_Maze_Solver/blob/main/Syntecxhub_Maze_Solver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import heapq

# Maze
# S = Start
# G = Goal
# # = Wall
# . = Open path

maze = [
    ['S', '.', '.', '#', '.'],
    ['#', '.', '.', '#', '.'],
    ['.', '.', '#', '.', '.'],
    ['.', '#', '.', '.', '.'],
    ['.', '.', '.', '#', 'G']
]

start = (0, 0)
goal = (4, 4)

# Manhattan distance heuristic
def heuristic(a, b):
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

# A* Search
def a_star(maze, start, goal):
    rows = len(maze)
    cols = len(maze[0])

    open_list = []
    heapq.heappush(open_list, (0, start))

    came_from = {}
    cost_so_far = {start: 0}

    directions = [
        (-1, 0),  # Up
        (1, 0),   # Down
        (0, -1),  # Left
        (0, 1)    # Right
    ]

    while open_list:
        _, current = heapq.heappop(open_list)

        if current == goal:
            path = []
            while current != start:
                path.append(current)
                current = came_from[current]
            path.append(start)
            path.reverse()
            return path

        for dr, dc in directions:
            neighbor = (current[0] + dr, current[1] + dc)

            # Check boundaries
            if not (0 <= neighbor[0] < rows and 0 <= neighbor[1] < cols):
                continue

            # Ignore walls
            if maze[neighbor[0]][neighbor[1]] == '#':
                continue

            new_cost = cost_so_far[current] + 1

            if neighbor not in cost_so_far or new_cost < cost_so_far[neighbor]:
                cost_so_far[neighbor] = new_cost
                priority = new_cost + heuristic(neighbor, goal)

                heapq.heappush(open_list, (priority, neighbor))
                came_from[neighbor] = current

    return None


# Find the shortest path
path = a_star(maze, start, goal)

# Display result
if path:
    print("Shortest path found!")
    print("Path:", path)
    print("Number of steps:", len(path) - 1)

    # Display maze with path
    result = [row[:] for row in maze]

    for r, c in path:
        if result[r][c] not in ['S', 'G']:
            result[r][c] = '*'

    print("\nMaze with shortest path:\n")

    for row in result:
        print(" ".join(row))
else:
    print("No path found. The goal is unreachable.")
# Out:
# Shortest path found!
# Path: [(0, 0), (0, 1), (1, 1), (2, 1), (2, 0), (3, 0), (4, 0), (4, 1), (4, 2), (3, 2), (3, 3), (3, 4), (4, 4)]
# Number of steps: 12
#
# Maze with shortest path:
#
# S * . # .
# # * . # .
# * * # . .
# * # * * *
# * * * # G

# %%
# Test an unreachable maze

unreachable_maze = [
    ['S', '#', '.', '.', '.'],
    ['#', '#', '.', '#', '.'],
    ['.', '.', '.', '#', '.'],
    ['.', '#', '.', '#', '.'],
    ['.', '.', '.', '#', 'G']
]

unreachable_path = a_star(unreachable_maze, (0, 0), (4, 4))

if unreachable_path:
    print("Path found:", unreachable_path)
else:
    print("No path found. The goal is unreachable.")
# Out:
# No path found. The goal is unreachable.
